# %% [markdown]
# <a href="https://colab.research.google.com/github/joseviniciusevangelista/tropicalia/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ano = "II"
print(ano, "competição de programação da Start")
## Aula 1
## Aula 2
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
# Out:
# II competição de programação da Start
# Os pontos totais do Rodrigo são 24
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3758626700.py in <cell line: 0>()
#       8 pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
#       9 print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
# ---> 10 total_de_figurinhas = int(input("Digite o total de figurinhas: "))
#      11 numero_de_amigos = int(input("Digite o número de amigos: "))
#      12 figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
# ...
